# %%
import damask
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
res = damask.Result('DP1000_DB/DP_linear_UAT_RD_tensionX.hdf5')

# %%
res.get('sigma')['increment_0']
# Out:
#  ██████████████████████████████████████████████████ 100% ETA 0:00:00
# {'BCC_Ferrite': array([[[-1.46199362e-04, -8.48675699e-07,  1.05338782e-05],
#          [-8.48675699e-07, -9.12871840e-05,  1.21647284e-06],
#          [ 1.05338782e-05,  1.21647284e-06, -1.22830785e-04]],
#
#         [[-1.46199362e-04, -8.48675699e-07,  1.05338782e-05],
#          [-8.48675699e-07, -9.12871840e-05,  1.21647284e-06],
#          [ 1.05338782e-05,  1.21647284e-06, -1.22830785e-04]],
#
#         [[-1.46199362e-04, -8.48675699e-07,  1.05338782e-05],
#          [-8.48675699e-07, -9.12871840e-05,  1.21647284e-06],
#          [ 1.05338782e-05,  1.21647284e-06, -1.22830785e-04]],
#
#         ...,
#
#         [[ 1.09519408e-04, -1.30582546e-05,  1.77934325e-05],
#          [-1.30582546e-05,  1.26257008e-04,  1.09345595e-05],
#          [ 1.77934325e-05,  1.09345595e-05,  9.68241974e-05]],
#
#         [[ 1.09519408e-04, -1.30582546e-05,  1.77934325e-05],
# ...
